# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis
import warnings
warnings.filterwarnings ("ignore")

# %%
data=pd.read_csv("Customer-Churn.csv")
data.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
#
# [1 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# data["SeniorCitizen"]=data["SeniorCitizen"].astype("object")

# %%
# data.info()

# %%
dp=data.describe()
dp
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='tenure', data=data)
plt.title('Boxplot of Tenure by Churn')
plt.xlabel('Churn')
plt.ylabel('Tenure')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='MonthlyCharges', data=data)
plt.title('Boxplot of Monthly Charges by Churn')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# feature selection
df=data.drop("customerID", axis=1)
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# colum create of calculate charge
df["calculatecharge"]=df["MonthlyCharges"]* df["tenure"]

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# ...

# %%
def hello(x):
    if len(x)<=1:
        return x

# %%
# total chareg--> it is object then convert to int/float

df["TotalCharges"].apply(lambda x : hello(x) )
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 7038    None
# 7039    None
# 7040    None
# 7041    None
# 7042    None
# Name: TotalCharges, Length: 7043, dtype: object

# %%
df["TotalCharges"]=pd.to_numeric(df['TotalCharges'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
# calculate charge check from Total charge
# If Total charge bigger then Calculate chareg then I put Greater, other wise Less
df["calculatecharge"]<df["TotalCharges"]
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040     True
# 7041     True
# 7042    False
# Length: 7043, dtype: bool

# %%
df["Total_charges_status"]=np.where(df["calculatecharge"]<df["TotalCharges"],"Biggest","Smallest")

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# ...

# %%
df["Total_charges_status"].value_counts()
# Out:
# Total_charges_status
# Smallest    3839
# Biggest     3204
# Name: count, dtype: int64

# %%
df[["Total_charges_status"]].value_counts().plot(kind ="pie",autopct="%.2f%%")
plt.show()

# %%
df.nunique() # in this database nunique value is ( 0 to 4)
# Out:
# gender                     2
# SeniorCitizen              2
# Partner                    2
# Dependents                 2
# tenure                    73
# PhoneService               2
# MultipleLines              3
# InternetService            3
# OnlineSecurity             3
# OnlineBackup               3
# DeviceProtection           3
# TechSupport                3
# StreamingTV                3
# StreamingMovies            3
# Contract                   3
# PaperlessBilling           2
# PaymentMethod              4
# MonthlyCharges          1585
# TotalCharges            6530
# Churn                      2
# calculatecharge         6051
# Total_charges_status       2
# dtype: int64

# %%
df.nunique().index  # nunique().index() bring column name
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'calculatecharge',
#        'Total_charges_status'],
#       dtype='object')

# %%
fd=df.nunique().reset_index()
colname=fd[fd[0]<=4]["index"]

# %%
for i in colname:
    print(i,":",df[i].unique())
# Out:
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']
# Total_charges_status : ['Smallest' 'Biggest']

# %%
# index change:- not internet service and no phone service convert to "NO"


for j in "MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies ".split():
    df[j].replace("No internet service","No",inplace=True)

# %%
df.MultipleLines.replace('No phone service',"No",inplace=True)

# %%
for i in colname:
    print(i,":",df[i].unique())
# Out:
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']
# Total_charges_status : ['Smallest' 'Biggest']

# %%
df.nunique()
# Out:
# gender                     2
# SeniorCitizen              2
# Partner                    2
# Dependents                 2
# tenure                    73
# PhoneService               2
# MultipleLines              2
# InternetService            3
# OnlineSecurity             2
# OnlineBackup               2
# DeviceProtection           2
# TechSupport                2
# StreamingTV                2
# StreamingMovies            2
# Contract                   3
# PaperlessBilling           2
# PaymentMethod              4
# MonthlyCharges          1585
# TotalCharges            6530
# Churn                      2
# calculatecharge         6051
# Total_charges_status       2
# dtype: int64

# %%
for i in df.columns:
    if df[i].nunique()>4:
        sns.displot(df[i], kde=True)

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0               No             DSL             No          Yes  ...
# ...

# %%
df.drop(["calculatecharge","Total_charges_status"],axis=1, inplace=True)

# %%
df.head(1)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0  Electronic check           29.85         29.85    No

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Churn"]=le.fit_transform(df["Churn"])

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 3            No             DSL            Yes           No              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
dfd=pd.get_dummies(df)

# %%
dfd.corr()
# Out:
#                                          SeniorCitizen    tenure  \
# SeniorCitizen                                 1.000000  0.016567
# tenure                                        0.016567  1.000000
# MonthlyCharges                                0.220173  0.247900
# TotalCharges                                  0.102411  0.825880
# Churn                                         0.150889 -0.352229
# gender_Female                                 0.001874 -0.005106
# gender_Male                                  -0.001874  0.005106
# Partner_No                                   -0.016479 -0.379697
# Partner_Yes                                   0.016479  0.379697
# Dependents_No                                 0.211185 -0.159712
# Dependents_Yes                               -0.211185  0.159712
# PhoneService_No                              -0.008576 -0.008448
# PhoneService_Yes                              0.008576  0.008448
# ...

# %%
sns.heatmap(dfd.corr(), linewidths=2)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 3            No             DSL            Yes           No              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
#  What is the customer churn rate?
df["Churn"].mean()
# Out:
# 0.2653698707936959

# %%
# How does Gender and Senior Citizen affect Churn rate?
df.groupby('gender')['Churn'].mean()
# Out:
# gender
# Female    0.269209
# Male      0.261603
# Name: Churn, dtype: float64

# %%
df.groupby('SeniorCitizen')['Churn'].mean()
# Out:
# SeniorCitizen
# 0    0.236062
# 1    0.416813
# Name: Churn, dtype: float64

# %%
churn_rate_with_dependents = df[df['Dependents'] == 'Yes']['Churn'].mean()

# Calculate churn rate for customers without dependents
churn_rate_without_dependents = df[df['Dependents'] == 'No']['Churn'].mean()
print(churn_rate_with_dependents)
print(churn_rate_without_dependents)
# Out:
# 0.15450236966824646
# 0.3127914048246503

# %%
dfd.corr()["Churn"].sort_values(ascending = False).plot(kind = "bar")
# Out:
# <Axes: >

# %%
# use it on the basis of gender.

df["gender"].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df[["gender","Churn"]].value_counts()
# Out:
# gender  Churn
# Male    0        2625
# Female  0        2549
#         1         939
# Male    1         930
# Name: count, dtype: int64

# %%
df[["gender","Churn"]].value_counts().plot(kind ="bar")
# Out:
# <Axes: xlabel='gender,Churn'>

# %% [raw]
# gender, churn
#
# SC-->
# SC+gender

# %%
# Paichart Base of Percentage
df[["gender","Churn"]].value_counts().plot(kind ="pie",autopct="%.2f%%")
plt.show()

# %%
df["SeniorCitizen"].value_counts()
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
df[["SeniorCitizen","gender"]].value_counts()
# Out:
# SeniorCitizen  gender
# 0              Male      2981
#                Female    2920
# 1              Male       574
#                Female     568
# Name: count, dtype: int64

# %%
df[["SeniorCitizen","gender","Churn"]].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='SeniorCitizen,gender,Churn'>

# %%
df[["SeniorCitizen","gender","Churn"]].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 3            No             DSL            Yes           No              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df[df["Churn"]==0]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0               No             DSL             No          Yes
# ...

# %%
df[df["Churn"]==0]["MonthlyCharges"]
# Out:
# 0        29.85
# 1        56.95
# 3        42.30
# 6        89.10
# 7        29.75
#          ...
# 7037     21.15
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7042    105.65
# Name: MonthlyCharges, Length: 5174, dtype: float64

# %%
sns.kdeplot(x=df[df["Churn"]==0]["MonthlyCharges"])
sns.kdeplot(x=df[df["Churn"]==1]["MonthlyCharges"], color="r")
plt.show()

# %%
sns.histplot(x=df[df["Churn"]==0]["MonthlyCharges"])
sns.histplot(x=df[df["Churn"]==1]["MonthlyCharges"])
plt.show()

# %% [raw]
# # Internet Sevices
# # Payment Method
# # TechSupport
# # Contract

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0               No             DSL             No          Yes
# ...

# %% [markdown]
# # Internet Services

# %%
df[["InternetService","Churn"]].value_counts()
# Out:
# InternetService  Churn
# DSL              0        1962
# Fiber optic      0        1799
# No               0        1413
# Fiber optic      1        1297
# DSL              1         459
# No               1         113
# Name: count, dtype: int64

# %%
df[df["Churn"]==0]["InternetService"]
df[df["Churn"]==1]["InternetService"]
print(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 3
#       1 df[df["Churn"]==0]["InternetService"]
#       2 df[df["Churn"]==1]["InternetService"]
# ----> 3 print(a,b)
#
# NameError: name 'a' is not defined

# %%
df[df["Churn"]==0]["InternetService"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df[df["Churn"]==1]["InternetService"].value_counts().plot(kind="pie",autopct="%.2f%%",)
# Out:
# <Axes: ylabel='count'>

# %%
graph=df[["InternetService","Churn"]].value_counts().plot(kind="bar")
for i in graph.containers:
    graph.bar_label(i)

# %% [markdown]
# # Payment Method

# %%
df[["PaymentMethod","Churn"]].value_counts()
# Out:
# PaymentMethod              Churn
# Mailed check               0        1304
# Electronic check           0        1294
# Credit card (automatic)    0        1290
# Bank transfer (automatic)  0        1286
# Electronic check           1        1071
# Mailed check               1         308
# Bank transfer (automatic)  1         258
# Credit card (automatic)    1         232
# Name: count, dtype: int64

# %%
a=df[df["Churn"]==0]["PaymentMethod"]
b=df[df["Churn"]==1]["PaymentMethod"]
print(a,b)
# Out:
# 0                Electronic check
# 1                    Mailed check
# 3       Bank transfer (automatic)
# 6         Credit card (automatic)
# 7                    Mailed check
#                   ...
# 7037    Bank transfer (automatic)
# 7038                 Mailed check
# 7039      Credit card (automatic)
# 7040             Electronic check
# 7042    Bank transfer (automatic)
# Name: PaymentMethod, Length: 5174, dtype: object 2                    Mailed check
# 4                Electronic check
# 5                Electronic check
# 8                Electronic check
# 13      Bank transfer (automatic)
#                   ...
# 7021             Electronic check
# 7026    Bank transfer (automatic)
# 7032             Electronic check
# 7034      Credit card (automatic)
# 7041                 Mailed check
# Name: PaymentMethod, Length: 1869, dtype: object

# %%
graph=df[["PaymentMethod","Churn"]].value_counts().plot(kind="bar")
for i in graph.containers:
    graph.bar_label(i)

# %%
df[df["Churn"]==0]["PaymentMethod"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df[df["Churn"]==1]["PaymentMethod"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(9.8, 6))

sns.histplot(x=df[df["Churn"]==0]["PaymentMethod"], color="blue", label="Non-Churned")
sns.histplot(x=df[df["Churn"]==1]["PaymentMethod"], color="red", label="Churned")
plt.legend()
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Distribution of Payment Method for Churned and Non-Churned Customers')
plt.show()
